# %% [markdown]
# テストセットは600個
# トレーニングセットが800個
# タイトルを日本語にして、置くこと（調べてやっておく）
#
# 乱数の種を変えること。

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# /Users/yamamotomasaomi/.pyenv/versions/anaconda3-5.1.0/envs/makuwo/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
# %config IPCompleter.greedy=True
# %matplotlib inline
# %matplotlib notebook

# %%
x = tf.placeholder(tf.float32,[None,5])

# %%
w = tf.Variable(tf.zeros([5,1]))

# %%
y = tf.matmul(x,w)

# %%
t = tf.placeholder(tf.float32,[None,1])

# %%
loss = tf.reduce_sum(tf.square(y-t))

# %%
train_step = tf.train.AdamOptimizer().minimize(loss)

# %%
sess = tf.Session()

# %%
sess.run(tf.global_variables_initializer())

# %%
train_t = ([5.2,5.7,8.6,14.9,18.2,20.4,25.5,26.4,22.8,17.5,11.1,6.6])
train_t= np.reshape(train_t,[12,1])
train_x = np.zeros([12,5])
for row, month in enumerate(range(1,13)):
    for col, n in enumerate(range(0,5)):
        train_x[row][col] = month**n

# %%
w_val = sess.run(w)

# %%
def predict(x):
    result = 0.0
    for n in range(0,5):
        result += w_val[n][0] * x**n
    return result

# %%
i = 0
train_y = []
time = []
for _ in range (200000):
    i += 1 
    sess.run(train_step,feed_dict={x:train_x,t:train_t})
    loss_val =sess.run(loss, feed_dict={x:train_x,t:train_t})
#     train_y.append(loss_val)
    if i % 1000 == 0:
        loss_val =sess.run(loss, feed_dict={x:train_x,t:train_t})
        train_y.append(loss_val)
        time.append(i)
        print ('Step:%d, Loss:%f'%(i, loss_val))
# Out:
# Step:1000, Loss:206.620728
# Step:2000, Loss:107.572891
# Step:3000, Loss:53.699402
# Step:4000, Loss:37.271095
# Step:5000, Loss:33.964218
# Step:6000, Loss:33.046951
# Step:7000, Loss:32.395897
# Step:8000, Loss:31.790615
# Step:9000, Loss:57.508007
# Step:10000, Loss:31.012833
# Step:11000, Loss:30.742279
# Step:12000, Loss:30.519266
# Step:13000, Loss:30.325497
# Step:14000, Loss:30.154434
# Step:15000, Loss:29.994699
# Step:16000, Loss:29.845955
# Step:17000, Loss:32.445179
# Step:18000, Loss:29.562103
# Step:19000, Loss:29.434137
# Step:20000, Loss:29.292377
# Step:21000, Loss:29.160034
# Step:22000, Loss:29.082596
# Step:23000, Loss:28.900730
# Step:24000, Loss:28.772795
# Step:25000, Loss:28.866587
# Step:26000, Loss:28.519047
# Step:27000, Loss:28.394455
# Step:28000, Loss:28.270130
# Step:29000, Loss:28.155384
# Step:30000, Loss:28.031116
# Step:31000, Loss:27.903530
# Step:32000, Loss:27.783339
# Step:33000, Loss:27.664192
# Step:34000, Loss:27.614531
# Step:35000, Loss:27.428486
# Step:36000, Loss:27.490967
# Step:37000, Loss:27.195457
# Step:38000, Loss:27.081535
# Step:39000, Loss:27.541687
# Step:40000, Loss:27.911423
# Step:41000, Loss:26.742117
# Step:128000, Loss:19.640959
# Step:129000, Loss:19.583984
# Step:130000, Loss:19.621506
# Step:131000, Loss:19.471081
# Step:132000, Loss:19.415209
# Step:133000, Loss:19.359377
# Step:134000, Loss:19.304007
# Step:135000, Loss:19.249538
# Step:136000, Loss:20.293686
# Step:137000, Loss:19.141676
# Step:138000, Loss:21.460571
# Step:139000, Loss:19.035553
# Step:140000, Loss:18.982832
# Step:141000, Loss:18.930603
# Step:142000, Loss:18.878704
# Step:143000, Loss:18.827440
# Step:144000, Loss:20.292030
# Step:145000, Loss:18.726244
# Step:146000, Loss:21.942001
# Step:147000, Loss:18.626617
# Step:148000, Loss:18.576693
# Step:149000, Loss:18.527617
# Step:150000, Loss:18.482285
# Step:151000, Loss:18.433891
# Step:152000, Loss:18.382046
# Step:153000, Loss:18.339886
# Step:154000, Loss:18.287868
# Step:155000, Loss:18.241089
# Step:156000, Loss:18.199535
# Step:157000, Loss:18.148375
# Step:158000, Loss:18.102377
# Step:159000, Loss:18.056660
# Step:160000, Loss:18.028996
# Step:161000, Loss:17.966789
# Step:162000, Loss:17.922499
# Step:163000, Loss:17.905191
# Step:164000, Loss:17.835278
# Step:165000, Loss:17.791330
# Step:166000, Loss:17.748222
# Step:167000, Loss:17.712502
# Step:168000, Loss:17.665777
# Step:169000, Loss:17.620430
# Step:170000, Loss:25.478247
# Step:171000, Loss:17.537216
# Step:172000, Loss:17.533907
# Step:173000, Loss:17.885494
# Step:174000, Loss:17.469873
# Step:175000, Loss:17.374704
# Step:176000, Loss:17.342419
# Step:177000, Loss:17.294670
# Step:178000, Loss:17.257835
# Step:179000, Loss:17.241375
# Step:180000, Loss:17.177750
# Step:181000, Loss:17.139145
# Step:182000, Loss:43.579880
# Step:183000, Loss:17.063108
# Step:184000, Loss:17.032904
# Step:185000, Loss:17.217310
# Step:186000, Loss:16.953110
# Step:187000, Loss:16.914366
# Step:188000, Loss:16.877914
# Step:189000, Loss:16.842411
# Step:190000, Loss:16.806355
# Step:191000, Loss:16.770741
# Step:192000, Loss:16.735573
# Step:193000, Loss:16.700129
# Step:194000, Loss:16.665201
# Step:195000, Loss:16.633011
# Step:196000, Loss:16.597099
# Step:197000, Loss:16.562359
# Step:198000, Loss:16.528629
# Step:199000, Loss:16.495213
# Step:200000, Loss:16.513100

# %%
fig = plt.figure(figsize=(8,6))
subplot = fig.add_subplot(1,1,1)
subplot.plot(time,train_y,linewidth=2)
# subplot.legend(loc='upper left')
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
fig = plt.figure(figsize=(8,6))
subplot = fig.add_subplot(1,1,1)
subplot.scatter(time,train_y,linewidth=2)
# subplot.legend(loc='upper left')
# Out:
# <img src="data:image/png;base64,..." width="576">
